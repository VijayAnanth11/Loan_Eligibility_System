# %%
from flask import Flask, request

app = Flask(__name__)

@app.route('/home')
def home():   
    return '''   
    
    <div>
    <div class="body"
        style="margin-left:9rem; margin-top:1rem; background-color:rgb(8, 216, 244); width:80%; border-radius:20px ">

        <div style="background-color:rgb(76, 77, 76);; display:flex; padding:1.5rem; color:white;">
            <a style="margin-left:2rem;font-size:20px; font-weight:bold">Home</a>
            <a style="margin-left:5rem;font-size:20px; font-weight:bold">Statics</a>
            <a style="margin-left:5rem;font-size:20px; font-weight:bold">Statements</a>
            <a style="margin-left:30rem;font-size:20px; font-weight:bold">Profile</a>
            <a style="margin-left:5rem;font-size:20px; font-weight:bold">Logout</a>
        </div>

        <form method="POST" action="/submit" style="margin-left:3rem; margin-top:4rem; ">

            <div style="display:flex; margin-top:1rem">
                <label style="font-size:20px; margin-left:2rem; margin-top: 0.5rem;" for="name">Name</label>
                <input type="text" id="name" name="name"
                    style="padding:10px; border-radius:15px; width:250px; padding-left:15px; margin-left: 0.5rem;"><br><br>
                <label style="font-size:20px; margin-left:3rem ; margin-top: 0.5rem" for="email">NIC No</label>
                <input type="email" id="email" name="email"
                    style="padding:10px; border-radius:15px; width:250px; padding-left:15px; margin-left:0.5rem"><br><br>
                <label style="font-size:20px; margin-left:3rem ; margin-top: 0.5rem" for="name">Age</label>
                <input type="text" id="name" name="name"
                    style="padding:10px; border-radius:15px; width:250px; padding-left:15px; margin-left: 0.5rem;"><br><br>
            </div>
            <div style="margin-top:2rem">
                <label style="margin-right:1rem; font-size:20px; margin-left:2rem">Gender</label>
                <input type="radio" id="male" name="gender" value="male"
                    style="transform: scale(2); margin-left: 0.5rem; ">
                <label style="margin-right:1rem; font-size:15px;" for="male">Male</label>
                <input type="radio" id="female" name="gender" value="female"
                    style="transform: scale(2); margin-left: 0.5rem;">
                <label style="margin-right:1rem; font-size:15px;" for="female">Female</label>

                <label style="margin-right:1rem; font-size:20px; margin-left:4rem">Marital status</label>
                <input type="radio" id="male" name="gender" value="male"
                    style="transform: scale(2); margin-left: 0.5rem; ">
                <label style="margin-right:1rem; font-size:15px;" for="male">Single</label>
                <input type="radio" id="female" name="gender" value="female"
                    style="transform: scale(2); margin-left: 0.5rem;">
                <label style="margin-right:1rem; font-size:15px;" for="female">Married</label>

                <label style="margin-right:1rem; font-size:20px; margin-left:4rem">Education</label>
                <input type="radio" id="male" name="gender" value="male"
                    style="transform: scale(2); margin-left: 0.5rem; ">
                <label style="margin-right:1rem; font-size:15px;" for="male">Primary</label>
                <input type="radio" id="female" name="gender" value="female"
                    style="transform: scale(2); margin-left: 0.5rem;">
                <label style="margin-right:1rem; font-size:15px;" for="female">Secondary</label>
                <input type="radio" id="female" name="gender" value="female"
                    style="transform: scale(2); margin-left: 0.5rem;">
                <label style="margin-right:1rem; font-size:15px;" for="female">Tertiary</label>
            </div>
            <div style="display:flex; margin-top:2rem">
                <label style="font-size:20px; margin-left:2rem; margin-top: 0.5rem;" for="name">Occupation</label>
                <input type="text" id="name" name="name"
                    style="padding:10px; border-radius:15px; width:205px; padding-left:15px; margin-left: 0.5rem;"><br><br>
                <label style="font-size:20px; margin-left:3rem ; margin-top: 0.5rem" for="email">Job Type</label>
                <input type="email" id="email" name="email"
                    style="padding:10px; border-radius:15px; width:250px; padding-left:15px; margin-left:0.5rem"><br><br>
                <label style="font-size:20px; margin-left:3rem ; margin-top: 0.5rem" for="name">Income</label>
                <input type="text" id="name" name="name"
                    style="padding:10px; border-radius:15px; width:210px; padding-left:15px; margin-left: 0.5rem;"><br><br>
            </div>
            <div style="display:flex; margin-top:4rem">
                <label style="font-size:20px; margin-left:2rem; margin-top: 0.5rem;" for="name">Loan Amount</label>
                <input type="text" id="name" name="name"
                    style="padding:10px; border-radius:15px; width:250px; padding-left:15px; margin-left: 0.5rem;"><br><br>
                <label style="font-size:20px; margin-left:3rem ; margin-top: 0.5rem" for="email">Loan Term</label>
                <input type="email" id="email" name="email"
                    style="padding:10px; border-radius:15px; width:250px; padding-left:15px; margin-left:1.7rem"><br><br>
            </div>
            <div style="display:flex; margin-top:2rem">
                <label style="font-size:20px; margin-left:2rem; margin-top: 0.5rem;" for="name">Dependents</label>
                <input type="text" id="name" name="name"
                    style="padding:10px; border-radius:15px; width:250px; padding-left:15px; margin-left: 1.5rem;"><br><br>
                <label style="font-size:20px; margin-left:3rem ; margin-top: 0.5rem" for="email">Loan Purpose</label>
                <input type="email" id="email" name="email"
                    style="padding:10px; border-radius:15px; width:250px; padding-left:15px; margin-left:0.5rem"><br><br>
            </div>
            <div style="display:flex; margin-top:2rem">
                <label style="font-size:20px; margin-left:2rem; margin-top: 0.5rem;" for="name">Credit Score</label>
                <input type="text" id="name" name="name"
                    style="padding:10px; border-radius:15px; width:250px; padding-left:15px; margin-left: 1.3rem;"><br><br>
            </div>


            <div style="display:flex; margin-top:2rem; margin-left: 20rem;">
                <input type=checkbox style="margin-left:2rem;transform: scale(1)">
                <label style="font-size:16px; color: rgb(118, 4, 4);"> By clicking here, I state that I have read and
                    understood the terms and condtions</label>
            </div>
            <div style="margin-left:34rem; margin-top: 1rem;">
                <label style="font-size:18px;color: rgb(7, 7, 80);">Terms and Conditions</label>
            </div>
            <div style="display:flex; margin-top:1rem; margin-left: 25rem; padding-bottom: 2rem;">
                <input type=submit value="Check The Status"
                    style="padding:10px; width:180px; background-color:rgb(10, 82, 6); color: white; font-weight:bold; border-radius:20px; font-size:15px;">
                <input type=submit value=Reset
                    style="padding:10px; width:110px; background-color:rgb(103, 103, 105); color: white; font-weight:bold; border-radius:20px; font-size:15px; margin-left:5rem">
            </div>


        </form>

    </div>
</div>                                                 
    
    '''
@app.route('/submit', methods=['POST'])
def submit():
    name = request.form['name']
    email = request.form['email']
    return f'Thank you for submitting your information, {name} ({email})!'

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
